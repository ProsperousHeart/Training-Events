# %% [markdown]
# <a href='https://devnetcreate.io/2019'><img src='https://github.com/ProsperousHeart/Personal-Projects/blob/master/CiscoDevNetCreate2019/IMGs/CiscoDevNetCreate2019.jpg?raw=true'></a>

# %% [markdown]
# # What Are Sequences?
#
# These are the *most basic* data structure where each element is assigned a number (called a **position** or **index**) starting at 0.
#
# # What Kinds Of Sequences?
#
# As per [python documentation](https://docs.python.org/3/library/stdtypes.html#sequence-types-list-tuple-range) there are several types of sequences, including but not limited to:
#
# - list
# - tuple
# - range
# - string

# %% [markdown]
# <img src='https://github.com/ProsperousHeart/Training-Events/blob/master/CiscoDevNetCreate2019/IMGs/sequence_numbering.png?raw=true'></img>

# %% [markdown]
# # What Can You Do With Sequences?
#
# Most sequence types can do the following:
# - indexing
# - slicing
# - adding
# - multiplying
# - checking for membership
#
# There are also built-in functions for most data object types, including but not limited to:
# - length
# - smallest element
#
# When you begin learning more advanced programming options, you can even create your own!
